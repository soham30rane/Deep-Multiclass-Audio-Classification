# %% [markdown]
# # Convolutional Neural Networks: Application
#
# Welcome to Course 4's second assignment! In this notebook, you will:
#
# - Create a mood classifer using the TF Keras Sequential API
# - Build a ConvNet to identify sign language digits using the TF Keras Functional API
#
# **After this assignment you will be able to:**
#
# - Build and train a ConvNet in TensorFlow for a __binary__ classification problem
# - Build and train a ConvNet in TensorFlow for a __multiclass__ classification problem
# - Explain different use cases for the Sequential and Functional APIs
#
# To complete this assignment, you should already be familiar with TensorFlow. If you are not, please refer back to the **TensorFlow Tutorial** of the third week of Course 2 ("**Improving deep neural networks**").
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/convolutional-neural-networks/supplement/DS4yP/h-ow-to-refresh-your-workspace).

# %% [markdown]
# ## Table of Contents
#
# - [1 - Packages](#1)
#     - [1.1 - Load the Data and Split the Data into Train/Test Sets](#1-1)
# - [2 - Layers in TF Keras](#2)
# - [3 - The Sequential API](#3)
#     - [3.1 - Create the Sequential Model](#3-1)
#         - [Exercise 1 - happyModel](#ex-1)
#     - [3.2 - Train and Evaluate the Model](#3-2)
# - [4 - The Functional API](#4)
#     - [4.1 - Load the SIGNS Dataset](#4-1)
#     - [4.2 - Split the Data into Train/Test Sets](#4-2)
#     - [4.3 - Forward Propagation](#4-3)
#         - [Exercise 2 - convolutional_model](#ex-2)
#     - [4.4 - Train the Model](#4-4)
# - [5 - History Object](#5)
# - [6 - Bibliography](#6)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages
#
# As usual, begin by loading in the packages.

# %%
### v1.1

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils import summary, comparator

# %matplotlib inline
np.random.seed(1)

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Load the Data and Split the Data into Train/Test Sets
#
# You'll be using the Happy House dataset for this part of the assignment, which contains images of peoples' faces. Your task will be to build a ConvNet that determines whether the people in the images are smiling or not -- because they only get to enter the house if they're smiling!

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_happy_dataset()

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %% [markdown]
# You can display the images contained in the dataset. Images are **64x64** pixels in RGB format (3 channels).

# %%
index = 124
plt.imshow(X_train_orig[index]) #display sample training image
plt.show()

# %% [markdown]
# <a name='2'></a>
# ## 2 - Layers in TF Keras
#
# In the previous assignment, you created layers manually in numpy. In TF Keras, you don't have to write code directly to create layers. Rather, TF Keras has pre-defined layers you can use.
#
# When you create a layer in TF Keras, you are creating a function that takes some input and transforms it into an output you can reuse later. Nice and easy!

# %% [markdown]
# <a name='3'></a>
# ## 3 - The Sequential API
#
# In the previous assignment, you built helper functions using `numpy` to understand the mechanics behind convolutional neural networks. Most practical applications of deep learning today are built using programming frameworks, which have many built-in functions you can simply call. Keras is a high-level abstraction built on top of TensorFlow, which allows for even more simplified and optimized model creation and training.
#
# For the first part of this assignment, you'll create a model using TF Keras' Sequential API, which allows you to build layer by layer, and is ideal for building models where each layer has **exactly one** input tensor and **one** output tensor.
#
# As you'll see, using the Sequential API is simple and straightforward, but is only appropriate for simpler, more straightforward tasks. Later in this notebook you'll spend some time building with a more flexible, powerful alternative: the Functional API.

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Create the Sequential Model
#
# As mentioned earlier, the TensorFlow Keras Sequential API can be used to build simple models with layer operations that proceed in a sequential order.
#
# You can also add layers incrementally to a Sequential model with the `.add()` method, or remove them using the `.pop()` method, much like you would in a regular Python list.
#
# Actually, you can think of a Sequential model as behaving like a list of layers. Like Python lists, Sequential layers are ordered, and the order in which they are specified matters.  If your model is non-linear or contains layers with multiple inputs or outputs, a Sequential model wouldn't be the right choice!
#
# For any layer construction in Keras, you'll need to specify the input shape in advance. This is because in Keras, the shape of the weights is based on the shape of the inputs. The weights are only created when the model first sees some input data. Sequential models can be created by passing a list of layers to the Sequential constructor, like you will do in the next assignment.
#
# <a name='ex-1'></a>
# ### Exercise 1 - happyModel
#
# Implement the `happyModel` function below to build the following model: `ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE`. Take help from [tf.keras.layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers)
#
# Also, plug in the following parameters for all the steps:
#
#  - [ZeroPadding2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ZeroPadding2D): padding 3, input shape 64 x 64 x 3
#  - [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D): Use 32 7x7 filters, stride 1
#  - [BatchNormalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization): for axis 3
#  - [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU)
#  - [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D): Using default parameters
#  - [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) the previous output.
#  - Fully-connected ([Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)) layer: Apply a fully connected layer with 1 neuron and a sigmoid activation.
#
#
#  **Hint:**
#
#  Use **tfl** as shorthand for **tensorflow.keras.layers**

# %%
# GRADED FUNCTION: happyModel

def happyModel():
    """
    Implements the forward propagation for the binary classification model:
    ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code all the values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    None

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    model = tf.keras.Sequential([
            ## ZeroPadding2D with padding 3, input shape of 64 x 64 x 3

            ## Conv2D with 32 7x7 filters and stride of 1

            ## BatchNormalization for axis 3

            ## ReLU

            ## Max Pooling 2D with default parameters

            ## Flatten layer

            ## Dense layer with 1 unit for output & 'sigmoid' activation
            
            # YOUR CODE STARTS HERE
            tfl.ZeroPadding2D(padding=3,input_shape=(64,64,3)),
            tfl.Conv2D(filters=32,kernel_size=(7,7),strides=1),
            tfl.BatchNormalization(axis=3),
            tfl.ReLU(),
            tfl.MaxPool2D(),
            tfl.Flatten(),
            tfl.Dense(units=1,activation="sigmoid"),
            # YOUR CODE ENDS HERE
        ])
    
    return model

# %%
happy_model = happyModel()
# Print a summary for each layer
for layer in summary(happy_model):
    print(layer)
    
output = [['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))],
            ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform'],
            ['BatchNormalization', (None, 64, 64, 32), 128],
            ['ReLU', (None, 64, 64, 32), 0],
            ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid'],
            ['Flatten', (None, 32768), 0],
            ['Dense', (None, 1), 32769, 'sigmoid']]
    
comparator(summary(happy_model), output)
# Out:
# ['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))]
# ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform']
# ['BatchNormalization', (None, 64, 64, 32), 128]
# ['ReLU', (None, 64, 64, 32), 0]
# ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid']
# ['Flatten', (None, 32768), 0]
# ['Dense', (None, 1), 32769, 'sigmoid']
# All tests passed!

# %% [markdown]
# #### Expected Output:
#
# ```
# ['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))]
# ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform']
# ['BatchNormalization', (None, 64, 64, 32), 128]
# ['ReLU', (None, 64, 64, 32), 0]
# ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid']
# ['Flatten', (None, 32768), 0]
# ['Dense', (None, 1), 32769, 'sigmoid']
# All tests passed!
# ```

# %% [markdown]
# Now that your model is created, you can compile it for training with an optimizer and loss of your choice. When the string `accuracy` is specified as a metric, the type of accuracy used will be automatically converted based on the loss function used. This is one of the many optimizations built into TensorFlow that make your life easier! If you'd like to read more on how the compiler operates, check the docs [here](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile).

# %%
happy_model.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %% [markdown]
# It's time to check your model's parameters with the `.summary()` method. This will display the types of layers you have, the shape of the outputs, and how many parameters are in each layer.

# %%
happy_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_8 (ZeroPaddin (None, 70, 70, 3)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 37,633
# Trainable params: 37,569
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Train and Evaluate the Model
#
# After creating the model, compiling it with your choice of optimizer and loss function, and doing a sanity check on its contents, you are now ready to build!
#
# Simply call `.fit()` to train. That's it! No need for mini-batching, saving, or complex backpropagation computations. That's all been done for you, as you're using a TensorFlow dataset with the batches specified already. You do have the option to specify epoch number or minibatch size if you like (for example, in the case of an un-batched dataset).

# %%
happy_model.fit(X_train, Y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 4s 95ms/step - loss: 0.7491 - accuracy: 0.7467
# Epoch 2/10
# 38/38 [==============================] - 4s 97ms/step - loss: 0.2223 - accuracy: 0.9167
# Epoch 3/10
# 38/38 [==============================] - 4s 97ms/step - loss: 0.1278 - accuracy: 0.9533
# Epoch 4/10
# 38/38 [==============================] - 4s 98ms/step - loss: 0.2480 - accuracy: 0.9083
# Epoch 5/10
# 38/38 [==============================] - 4s 97ms/step - loss: 0.1071 - accuracy: 0.9600
# Epoch 6/10
# 38/38 [==============================] - 4s 95ms/step - loss: 0.1674 - accuracy: 0.9283
# Epoch 7/10
# 38/38 [==============================] - 4s 97ms/step - loss: 0.1566 - accuracy: 0.9467
# Epoch 8/10
# 38/38 [==============================] - 4s 95ms/step - loss: 0.1141 - accuracy: 0.9600
# Epoch 9/10
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0731 - accuracy: 0.9750
# Epoch 10/10
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0855 - accuracy: 0.9733

# %% [markdown]
# After that completes, just use `.evaluate()` to evaluate against your test set. This function will print the value of the loss function and the performance metrics specified during the compilation of the model. In this case, the `binary_crossentropy` and the `accuracy` respectively.

# %%
happy_model.evaluate(X_test, Y_test)
# Out:
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3007 - accuracy: 0.8800
# [0.30072250962257385, 0.8799999952316284]

# %% [markdown]
# Easy, right? But what if you need to build a model with shared layers, branches, or multiple inputs and outputs? This is where Sequential, with its beautifully simple yet limited functionality, won't be able to help you.
#
# Next up: Enter the Functional API, your slightly more complex, highly flexible friend.

# %% [markdown]
# <a name='4'></a>
# ## 4 - The Functional API

# %% [markdown]
# Welcome to the second half of the assignment, where you'll use Keras' flexible [Functional API](https://www.tensorflow.org/guide/keras/functional) to build a ConvNet that can differentiate between 6 sign language digits.
#
# The Functional API can handle models with non-linear topology, shared layers, as well as layers with multiple inputs or outputs. Imagine that, where the Sequential API requires the model to move in a linear fashion through its layers, the Functional API allows much more flexibility. Where Sequential is a straight line, a Functional model is a graph, where the nodes of the layers can connect in many more ways than one.
#
# In the visual example below, the one possible direction of the movement Sequential model is shown in contrast to a skip connection, which is just one of the many ways a Functional model can be constructed. A skip connection, as you might have guessed, skips some layer in the network and feeds the output to a later layer in the network. Don't worry, you'll be spending more time with skip connections very soon!

# %% [markdown]
# <img src="images/seq_vs_func.png" style="width:350px;height:200px;">

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 - Load the SIGNS Dataset
#
# As a reminder, the SIGNS dataset is a collection of 6 signs representing numbers from 0 to 5.

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_signs_dataset()

# %% [markdown]
# <img src="images/SIGNS.png" style="width:800px;height:300px;">
#
# The next cell will show you an example of a labelled image in the dataset. Feel free to change the value of `index` below and re-run to see different examples.

# %%
# Example of an image from the dataset
index = 9
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 4

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Split the Data into Train/Test Sets
#
# In Course 2, you built a fully-connected network for this dataset. But since this is an image dataset, it is more natural to apply a ConvNet to it.
#
# To get started, let's examine the shapes of your data.

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Forward Propagation
#
# In TensorFlow, there are built-in functions that implement the convolution steps for you. By now, you should be familiar with how TensorFlow builds computational graphs. In the [Functional API](https://www.tensorflow.org/guide/keras/functional), you create a graph of layers. This is what allows such great flexibility.
#
# However, the following model could also be defined using the Sequential API since the information flow is on a single line. But don't deviate. What we want you to learn is to use the functional API.
#
# Begin building your graph of layers by creating an input node that functions as a callable object:
#
# - **input_img = tf.keras.Input(shape=input_shape):**
#
# Then, create a new node in the graph of layers by calling a layer on the `input_img` object:
#
# - **tf.keras.layers.Conv2D(filters= ... , kernel_size= ... , padding='same')(input_img):** Read the full documentation on [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D).
#
# - **tf.keras.layers.MaxPool2D(pool_size=(f, f), strides=(s, s), padding='same'):** `MaxPool2D()` downsamples your input using a window of size (f, f) and strides of size (s, s) to carry out max pooling over each window.  For max pooling, you usually operate on a single example at a time and a single channel at a time. Read the full documentation on [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D).
#
# - **tf.keras.layers.ReLU():** computes the elementwise ReLU of Z (which can be any shape). You can read the full documentation on [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU).
#
# - **tf.keras.layers.Flatten()**: given a tensor "P", this function takes each training (or test) example in the batch and flattens it into a 1D vector.
#
#     * If a tensor P has the shape (batch_size,h,w,c), it returns a flattened tensor with shape (batch_size, k), where $k=h \times w \times c$.  "k" equals the product of all the dimension sizes other than the first dimension.
#
#     * For example, given a tensor with dimensions [100, 2, 3, 4], it flattens the tensor to be of shape [100, 24], where 24 = 2 * 3 * 4.  You can read the full documentation on [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten).
#
# - **tf.keras.layers.Dense(units= ... , activation='softmax')(F):** given the flattened input F, it returns the output computed using a fully connected layer. You can read the full documentation on [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense).
#
# In the last function above (`tf.keras.layers.Dense()`), the fully connected layer automatically initializes weights in the graph and keeps on training them as you train the model. Hence, you did not need to initialize those weights when initializing the parameters.
#
# Lastly, before creating the model, you'll need to define the output using the last of the function's compositions (in this example, a Dense layer):
#
# - **outputs = tf.keras.layers.Dense(units=6, activation='softmax')(F)**
#
#
# #### Window, kernel, filter, pool
#
# The words "kernel" and "filter" are used to refer to the same thing. The word "filter" accounts for the amount of "kernels" that will be used in a single convolution layer. "Pool" is the name of the operation that takes the max or average value of the kernels.
#
# This is why the parameter `pool_size` refers to `kernel_size`, and you use `(f,f)` to refer to the filter size.
#
# Pool size and kernel size refer to the same thing in different objects - They refer to the shape of the window where the operation takes place.

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - convolutional_model
#
# Implement the `convolutional_model` function below to build the following model: `CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE`. Use the functions above!
#
# Also, plug in the following parameters for all the steps:
#
#  - [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D): Use 8 4 by 4 filters, stride 1, padding is "SAME"
#  - [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU)
#  - [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D): Use an 8 by 8 filter size and an 8 by 8 stride, padding is "SAME"
#  - **Conv2D**: Use 16 2 by 2 filters, stride 1, padding is "SAME"
#  - **ReLU**
#  - **MaxPool2D**: Use a 4 by 4 filter size and a 4 by 4 stride, padding is "SAME"
#  - [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) the previous output.
#  - Fully-connected ([Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)) layer: Apply a fully connected layer with 6 neurons and a softmax activation.

# %%
# GRADED FUNCTION: convolutional_model

def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """

    input_img = tf.keras.Input(shape=input_shape)
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    # Z1 = None
    ## RELU
    # A1 = None
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    # P1 = None
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    # Z2 = None
    ## RELU
    # A2 = None
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    # P2 = None
    ## FLATTEN
    # F = None
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    # outputs = None
    # YOUR CODE STARTS HERE
    # CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    Z1 = tfl.Conv2D(filters=8,kernel_size=(4,4),strides=1,padding="same")(input_img)
    # RELU
    A1 = tfl.ReLU()(Z1)
    # MAXPOOL: window 8x8, stride 8, padding 'SAME'
    P1 = tfl.MaxPool2D(pool_size=(8,8),strides=(8,8),padding="same")(A1)
    # CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    Z2 = tfl.Conv2D(filters=16,kernel_size=(2,2),strides=1,padding="same")(P1)
    # RELU
    A2 = tfl.ReLU()(Z2)
    # MAXPOOL: window 4x4, stride 4, padding 'SAME'
    P2 = tfl.MaxPool2D(pool_size=(4,4),strides=(4,4),padding="same")(A2)
    # FLATTEN
    F = tfl.Flatten()(P2)
    # Dense layer
    # 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    outputs = tfl.Dense(units=6,activation="softmax")(F)
    
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
    
output = [['InputLayer', [(None, 64, 64, 3)], 0],
        ['Conv2D', (None, 64, 64, 8), 392, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 64, 64, 8), 0],
        ['MaxPooling2D', (None, 8, 8, 8), 0, (8, 8), (8, 8), 'same'],
        ['Conv2D', (None, 8, 8, 16), 528, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 8, 8, 16), 0],
        ['MaxPooling2D', (None, 2, 2, 16), 0, (4, 4), (4, 4), 'same'],
        ['Flatten', (None, 64), 0],
        ['Dense', (None, 6), 390, 'softmax']]
    
comparator(summary(conv_model), output)
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 8)         392
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 64, 64, 8)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 16)          528
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 8, 8, 16)          0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 2, 2, 16)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________
# All tests passed!

# %% [markdown]
# Both the Sequential and Functional APIs return a TF Keras model object. The only difference is how inputs are handled inside the object model!

# %% [markdown]
# <a name='4-4'></a>
# ### 4.4 - Train the Model

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 2s 117ms/step - loss: 1.8060 - accuracy: 0.1167 - val_loss: 1.7940 - val_accuracy: 0.1667
# Epoch 2/100
# 17/17 [==============================] - 2s 112ms/step - loss: 1.7950 - accuracy: 0.1593 - val_loss: 1.7907 - val_accuracy: 0.1750
# Epoch 3/100
# 17/17 [==============================] - 2s 112ms/step - loss: 1.7916 - accuracy: 0.1769 - val_loss: 1.7887 - val_accuracy: 0.2083
# Epoch 4/100
# 17/17 [==============================] - 2s 106ms/step - loss: 1.7884 - accuracy: 0.1898 - val_loss: 1.7870 - val_accuracy: 0.2083
# Epoch 5/100
# 17/17 [==============================] - 2s 106ms/step - loss: 1.7852 - accuracy: 0.2102 - val_loss: 1.7851 - val_accuracy: 0.2083
# Epoch 6/100
# 17/17 [==============================] - 2s 106ms/step - loss: 1.7810 - accuracy: 0.2185 - val_loss: 1.7824 - val_accuracy: 0.2250
# Epoch 7/100
# 17/17 [==============================] - 2s 106ms/step - loss: 1.7752 - accuracy: 0.2685 - val_loss: 1.7774 - val_accuracy: 0.2500
# Epoch 8/100
# 17/17 [==============================] - 2s 106ms/step - loss: 1.
100
# 17/17 [==============================] - 2s 107ms/step - loss: 0.3515 - accuracy: 0.9000 - val_loss: 0.4880 - val_accuracy: 0.8167
# Epoch 95/100
# 17/17 [==============================] - 2s 107ms/step - loss: 0.3485 - accuracy: 0.9009 - val_loss: 0.4846 - val_accuracy: 0.8167
# Epoch 96/100
# 17/17 [==============================] - 2s 107ms/step - loss: 0.3455 - accuracy: 0.9009 - val_loss: 0.4818 - val_accuracy: 0.8167
# Epoch 97/100
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3422 - accuracy: 0.9046 - val_loss: 0.4785 - val_accuracy: 0.8167
# Epoch 98/100
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3390 - accuracy: 0.9056 - val_loss: 0.4760 - val_accuracy: 0.8250
# Epoch 99/100
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3364 - accuracy: 0.9074 - val_loss: 0.4731 - val_accuracy: 0.8250
# Epoch 100/100
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3337 - accuracy: 0.9074 - val_loss: 0.4707 - val_accuracy: 0.8250

# %% [markdown]
# <a name='5'></a>
# ## 5 - History Object
#
# The history object is an output of the `.fit()` operation, and provides a record of all the loss and metric values in memory. It's stored as a dictionary that you can retrieve at `history.history`:

# %%
history.history
# Out:
# {'loss': [1.8060182332992554,
#   1.7949997186660767,
#   1.7916271686553955,
#   1.7883930206298828,
#   1.7851827144622803,
#   1.781036376953125,
#   1.775159239768982,
#   1.7665191888809204,
#   1.7528057098388672,
#   1.7321674823760986,
#   1.7055864334106445,
#   1.6713746786117554,
#   1.6288394927978516,
#   1.5805530548095703,
#   1.529189109802246,
#   1.4783947467803955,
#   1.4297277927398682,
#   1.3831560611724854,
#   1.3390859365463257,
#   1.297377109527588,
#   1.2581017017364502,
#   1.2210437059402466,
#   1.1825668811798096,
#   1.1477588415145874,
#   1.114734411239624,
#   1.0797382593154907,
#   1.0477391481399536,
#   1.0156997442245483,
#   0.9868524670600891,
#   0.9585978388786316,
#   0.9311924576759338,
#   0.9065332412719727,
#   0.8809276819229126,
#   0.8595382571220398,
#   0.836184024810791,
#   0.8161191940307617,
#   0.7947922348976135,
#   0.7765039205551147,
#   0.7577746510505676,
#   0.7415808439254761,
#   0.724439263343811,
#   0.710053026676178,
#   0.6946184039115906,
#   0.680957019329071,
#   0.6671490669250488,
#   0.654242217540741,
#   0.6409149765968323,
#   0.6282907724380493,
#   0.615286648273468,
#   0.6048606634140015,
#   0.5927311778068542,
#   0.5824998021125793,
#   0.5718939304351807,
#   0.5622166991233826,
#   0.5529248118400574,
#   0.5444803237915039,
#   0.5353705286979675,
#   0.5264467000961304,
#   0.5189969539642334,
#   0.5114871263504028,
#   0.5038492679595947,
#   0.4968118667602539,
#   0.490556001663208,
#   0.4838736057281494,
#   0.4777708947658539,
#   0.47162458300590515,
#   0.46587592363357544,
#   0.46031299233436584,
#   0.4544527232646942,
#   0.44892629981040955,
#   0.4435182511806488,
#   0.4380263388156891,
#   0.43308722972869873,
#   0.4281286299228668,
#   0.42378315329551697,
#   0.41917169094085693,
#   0.41508904099464417,
#   0.41052818298339844,
#   0.4064173400402069,
#   0.40206244587898254,
#   0.39802050590515137,
#   0.39380985498428345,
#   0.3900854289531708,
#   0.38617420196533203,
#   0.3820055425167084,
#   0.3780864477157593,
#   0.37449637055397034,
#   0.3711741864681244,
#   0.36743462085723877,
#   0.3640904724597931,
#   0.36072924733161926,
#   0.35766085982322693,
#   0.35473477840423584,
#   0.35145658254623413,
#   0.34854915738105774,
20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3280 - accuracy: 0.9074 - val_loss: 0.4655 - val_accuracy: 0.8250
# Epoch 3/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3253 - accuracy: 0.9093 - val_loss: 0.4625 - val_accuracy: 0.8250
# Epoch 4/20
# 17/17 [==============================] - 2s 112ms/step - loss: 0.3228 - accuracy: 0.9083 - val_loss: 0.4600 - val_accuracy: 0.8250
# Epoch 5/20
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3200 - accuracy: 0.9093 - val_loss: 0.4573 - val_accuracy: 0.8250
# Epoch 6/20
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3174 - accuracy: 0.9111 - val_loss: 0.4544 - val_accuracy: 0.8250
# Epoch 7/20
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3149 - accuracy: 0.9111 - val_loss: 0.4516 - val_accuracy: 0.8250
# Epoch 8/20
# 17/17 [==============================] - 2s 106ms/step - loss: 0.3125 - accuracy: 0.9130 - val_loss: 0.4493 - val_accuracy: 0.8250
# Epoch 9/20
# 17/17 [==============================] - 2s 107ms/step - loss: 0.3104 - accuracy: 0.9148 - val_loss: 0.4466 - val_accuracy: 0.8250
# Epoch 10/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3081 - accuracy: 0.9148 - val_loss: 0.4443 - val_accuracy: 0.8250
# Epoch 11/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3057 - accuracy: 0.9167 - val_loss: 0.4422 - val_accuracy: 0.8250
# Epoch 12/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3034 - accuracy: 0.9167 - val_loss: 0.4395 - val_accuracy: 0.8250
# Epoch 13/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3010 - accuracy: 0.9185 - val_loss: 0.4380 - val_accuracy: 0.8250
# Epoch 14/20
# 17/17 [==============================] - 2s 112ms/step - loss: 0.2987 - accuracy: 0.9194 - val_loss: 0.4356 - val_accuracy: 0.8250
# Epoch 15/20
# 17/17 [==============================] - 2s 106ms/step - loss: 0.2964 - accuracy: 0.9204 - val_loss: 0.4338 - val_accuracy: 0.8250
# Epoch 16/20
# 17/17 [==============================] - 2s 106ms/step - loss: 0.2942 - accuracy: 0.9213 - val_loss: 0.4317 - val_accuracy: 0.8250
# Epoch 17/20
# 17/17 [==============================] - 2s 112ms/step - loss: 0.2920 - accuracy: 0.9213 - val_loss: 0.4300 - val_accuracy: 0.8250
# Epoch 18/20
# 17/17 [==============================] - 2s 112ms/step - loss: 0.2898 - accuracy: 0.9222 - val_loss: 0.4280 - val_accuracy: 0.8333
# Epoch 19/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2877 - accuracy: 0.9241 - val_loss: 0.4264 - val_accuracy: 0.8333
# Epoch 20/20
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2853 - accuracy: 0.9259 - val_loss: 0.4245 - val_accuracy: 0.8333

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history2.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# [Text(0, 0.5, 'Accuracy'), Text(0.5, 0, 'Epoch')]

# %%
history3 = conv_model.fit(train_dataset, epochs=500, validation_data=test_dataset)
# Out:
# Epoch 1/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2832 - accuracy: 0.9250 - val_loss: 0.4232 - val_accuracy: 0.8333
# Epoch 2/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2810 - accuracy: 0.9231 - val_loss: 0.4215 - val_accuracy: 0.8333
# Epoch 3/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2791 - accuracy: 0.9250 - val_loss: 0.4203 - val_accuracy: 0.8333
# Epoch 4/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2769 - accuracy: 0.9259 - val_loss: 0.4190 - val_accuracy: 0.8333
# Epoch 5/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2749 - accuracy: 0.9259 - val_loss: 0.4169 - val_accuracy: 0.8333
# Epoch 6/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2731 - accuracy: 0.9259 - val_loss: 0.4163 - val_accuracy: 0.8333
# Epoch 7/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.2711 - accuracy: 0.9250 - val_loss: 0.4148 - val_accuracy: 0.8333
# Epoch 8/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.2693 - accuracy: 0.9269 - val_loss: 0.4129 - val_accuracy: 0.8333
# Epoch 9/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.2674 - accuracy: 0.9250 - val_loss: 0.4124 - val_accuracy: 0.8417
# Epoch 10/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.
500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1777 - accuracy: 0.9546 - val_loss: 0.3321 - val_accuracy: 0.8667
# Epoch 73/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1764 - accuracy: 0.9537 - val_loss: 0.3309 - val_accuracy: 0.8667
# Epoch 74/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1753 - accuracy: 0.9537 - val_loss: 0.3307 - val_accuracy: 0.8667
# Epoch 75/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1741 - accuracy: 0.9537 - val_loss: 0.3299 - val_accuracy: 0.8667
# Epoch 76/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1729 - accuracy: 0.9537 - val_loss: 0.3295 - val_accuracy: 0.8667
# Epoch 77/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1719 - accuracy: 0.9537 - val_loss: 0.3291 - val_accuracy: 0.8667
# Epoch 78/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1709 - accuracy: 0.9546 - val_loss: 0.3288 - val_accuracy: 0.8667
# Epoch 79/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1702 - accuracy: 0.9546 - val_loss: 0.3283 - val_accuracy: 0.8667
# Epoch 80/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1692 - accuracy: 0.9556 - val_loss: 0.3278 - val_accuracy: 0.8667
# Epoch 81/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1683 - accuracy: 0.9556 - val_loss: 0.3275 - val_accuracy: 0.8667
# Epoch 82/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1674 - accuracy: 0.9556 - val_loss: 0.3271 - val_accuracy: 0.8667
# Epoch 83/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1663 - accuracy: 0.9556 - val_loss: 0.3264 - val_accuracy: 0.8667
# Epoch 84/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1651 - accuracy: 0.9565 - val_loss: 0.3253 - val_accuracy: 0.8667
# Epoch 85/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1644 - accuracy: 0.9556 - val_loss: 0.3255 - val_accuracy: 0.8667
# Epoch 86/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1632 - accuracy: 0.9574 - val_loss: 0.3244 - val_accuracy: 0.8667
# Epoch 87/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1628 - accuracy: 0.9565 - val_loss: 0.3242 - val_accuracy: 0.8667
# Epoch 88/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1622 - accuracy: 0.9565 - val_loss: 0.3241 - val_accuracy: 0.8667
# Epoch 89/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1611 - accuracy: 0.9565 - val_loss: 0.3234 - val_accuracy: 0.8750
# Epoch 90/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1600 - accuracy: 0.9574 - val_loss: 0.3224 - val_accuracy: 0.8750
# Epoch 91/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1594 - accuracy: 0.9574 - val_loss: 0.3219 - val_accuracy: 0.8750
# Epoch 92/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1588 - accuracy: 0.9583 - val_loss: 0.3221 - val_accuracy: 0.8750
# Epoch 93/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1581 - accuracy: 0.9583 - val_loss: 0.3222 - val_accuracy: 0.8750
# Epoch 94/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1571 - accuracy: 0.9593 - val_loss: 0.3211 - val_accuracy: 0.8750
# Epoch 95/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1562 - accuracy: 0.9583 - val_loss: 0.3223 - val_accuracy: 0.8750
# Epoch 96/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1554 - accuracy: 0.9593 - val_loss: 0.3208 - val_accuracy: 0.8750
# Epoch 97/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1547 - accuracy: 0.9593 - val_loss: 0.3214 - val_accuracy: 0.8750
# Epoch 98/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1542 - accuracy: 0.9593 - val_loss: 0.3203 - val_accuracy: 0.8750
# Epoch 99/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1533 - accuracy: 0.9593 - val_loss: 0.3215 - val_accuracy: 0.8750
# Epoch 100/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1527 - accuracy: 0.9593 - val_loss: 0.3208 - val_accuracy: 0.8750
# Epoch 101/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1516 - accuracy: 0.9593 - val_loss: 0.3212 - val_accuracy: 0.8750
# Epoch 102/500
# 17/17 [==============================] - 2s 108ms/step - loss: 0.1509 - accuracy: 0.9593 - val_loss: 0.3209 - val_accuracy: 0.8750
# Epoch 103/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1502 - accuracy: 0.9593 - val_loss: 0.3210 - val_accuracy: 0.8750
# Epoch 104/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1496 - accuracy: 0.9602 - val_loss: 0.3211 - val_accuracy: 0.8750
# Epoch 105/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1489 - accuracy: 0.9593 - val_loss: 0.3216 - val_accuracy: 0.8750
# Epoch 106/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1479 - accuracy: 0.9593 - val_loss: 0.3211 - val_accuracy: 0.8750
# Epoch 107/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1473 - accuracy: 0.9611 - val_loss: 0.3220 - val_accuracy: 0.8750
# Epoch 108/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1464 - accuracy: 0.9620 - val_loss: 0.3217 - val_accuracy: 0.8750
# Epoch 109/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1453 - accuracy: 0.9620 - val_loss: 0.3218 - val_accuracy: 0.8750
# Epoch 110/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1447 - accuracy: 0.9630 - val_loss: 0.3211 - val_accuracy: 0.8750
# Epoch 111/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1437 - accuracy: 0.9630 - val_loss: 0.3222 - val_accuracy: 0.8750
# Epoch 112/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1431 - accuracy: 0.9630 - val_loss: 0.3216 - val_accuracy: 0.8750
# Epoch 113/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1420 - accuracy: 0.9630 - val_loss: 0.3235 - val_accuracy: 0.8750
# Epoch 114/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1416 - accuracy: 0.9630 - val_loss: 0.3220 - val_accuracy: 0.8750
# Epoch 115/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1407 - accuracy: 0.9657 - val_loss: 0.3228 - val_accuracy: 0.8750
# Epoch 116/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1398 - accuracy: 0.9657 - val_loss: 0.3225 - val_accuracy: 0.8833
# Epoch 117/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1389 - accuracy: 0.9667 - val_loss: 0.3232 - val_accuracy: 0.8833
# Epoch 118/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1379 - accuracy: 0.9667 - val_loss: 0.3228 - val_accuracy: 0.8833
# Epoch 119/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1371 - accuracy: 0.9667 - val_loss: 0.3239 - val_accuracy: 0.8833
# Epoch 120/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1362 - accuracy: 0.9676 - val_loss: 0.3231 - val_accuracy: 0.8833
# Epoch 121/500
# 17/17 [==============================] - 2s 108ms/step - loss: 0.1354 - accuracy: 0.9676 - val_loss: 0.3242 - val_accuracy: 0.8833
# Epoch 122/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1344 - accuracy: 0.9676 - val_loss: 0.3243 - val_accuracy: 0.8833
# Epoch 123/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1335 - accuracy: 0.9676 - val_loss: 0.3236 - val_accuracy: 0.8833
# Epoch 124/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1326 - accuracy: 0.9676 - val_loss: 0.3237 - val_accuracy: 0.8833
# Epoch 125/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1318 - accuracy: 0.9685 - val_loss: 0.3253 - val_accuracy: 0.8917
# Epoch 126/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1310 - accuracy: 0.9685 - val_loss: 0.3235 - val_accuracy: 0.8917
# Epoch 127/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1301 - accuracy: 0.9685 - val_loss: 0.3263 - val_accuracy: 0.8917
# Epoch 128/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1298 - accuracy: 0.9685 - val_loss: 0.3243 - val_accuracy: 0.8917
# Epoch 129/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1287 - accuracy: 0.9685 - val_loss: 0.3265 - val_accuracy: 0.8917
# Epoch 130/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1283 - accuracy: 0.9694 - val_loss: 0.3238 - val_accuracy: 0.8917
# Epoch 131/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1269 - accuracy: 0.9694 - val_loss: 0.3247 - val_accuracy: 0.8917
# Epoch 132/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1261 - accuracy: 0.9704 - val_loss: 0.3236 - val_accuracy: 0.8917
# Epoch 133/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1251 - accuracy: 0.9704 - val_loss: 0.3265 - val_accuracy: 0.8917
# Epoch 134/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1248 - accuracy: 0.9704 - val_loss: 0.3237 - val_accuracy: 0.8917
# Epoch 135/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1237 - accuracy: 0.9694 - val_loss: 0.3265 - val_accuracy: 0.8917
# Epoch 136/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1227 - accuracy: 0.9704 - val_loss: 0.3257 - val_accuracy: 0.8917
# Epoch 137/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1218 - accuracy: 0.9704 - val_loss: 0.3259 - val_accuracy: 0.8917
# Epoch 138/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1209 - accuracy: 0.9713 - val_loss: 0.3259 - val_accuracy: 0.8917
# Epoch 139/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1203 - accuracy: 0.9713 - val_loss: 0.3248 - val_accuracy: 0.8917
# Epoch 140/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1192 - accuracy: 0.9713 - val_loss: 0.3261 - val_accuracy: 0.8917
# Epoch 141/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1183 - accuracy: 0.9713 - val_loss: 0.3237 - val_accuracy: 0.8917
# Epoch 142/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1175 - accuracy: 0.9713 - val_loss: 0.3248 - val_accuracy: 0.8917
# Epoch 143/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.1167 - accuracy: 0.9722 - val_loss: 0.3241 - val_accuracy: 0.8917
# Epoch 144/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.1159 - accuracy: 0.9722 - val_loss: 0.3227 - val_accuracy: 0.8917
# Epoch 145/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.1150 - accuracy: 0.9722 - val_loss: 0.3229 - val_accuracy: 0.8917
# Epoch 146/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1142 - accuracy: 0.9722 - val_loss: 0.3224 - val_accuracy: 0.8917
# Epoch 147/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1133 - accuracy: 0.9722 - val_loss: 0.3217 - val_accuracy: 0.8917
# Epoch 148/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1125 - accuracy: 0.9722 - val_loss: 0.3215 - val_accuracy: 0.8917
# Epoch 149/500
# 17/17 [==============================] - 2s 96ms/step - loss: 0.1117 - accuracy: 0.9722 - val_loss: 0.3211 - val_accuracy: 0.8917
# Epoch 150/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1109 - accuracy: 0.9722 - val_loss: 0.3199 - val_accuracy: 0.8917
# Epoch 151/500
# 17/17 [==============================] - 2s 101ms/step - loss: 0.1101 - accuracy: 0.9722 - val_loss: 0.3208 - val_accuracy: 0.8917
# Epoch 152/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1095 - accuracy: 0.9731 - val_loss: 0.3199 - val_accuracy: 0.8917
# Epoch 153/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1087 - accuracy: 0.9722 - val_loss: 0.3190 - val_accuracy: 0.8917
# Epoch 154/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1081 - accuracy: 0.9731 - val_loss: 0.3194 - val_accuracy: 0.8917
# Epoch 155/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1074 - accuracy: 0.9722 - val_loss: 0.3185 - val_accuracy: 0.9000
# Epoch 156/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1067 - accuracy: 0.9731 - val_loss: 0.3190 - val_accuracy: 0.9000
# Epoch 157/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1060 - accuracy: 0.9741 - val_loss: 0.3171 - val_accuracy: 0.9000
# Epoch 158/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1053 - accuracy: 0.9741 - val_loss: 0.3196 - val_accuracy: 0.9083
# Epoch 159/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.1050 - accuracy: 0.9741 - val_loss: 0.3174 - val_accuracy: 0.9083
# Epoch 160/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1036 - accuracy: 0.9759 - val_loss: 0.3177 - val_accuracy: 0.9083
# Epoch 161/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1029 - accuracy: 0.9759 - val_loss: 0.3166 - val_accuracy: 0.9083
# Epoch 162/500
# 17/17 [==============================] - 2s 96ms/step - loss: 0.1020 - accuracy: 0.9759 - val_loss: 0.3171 - val_accuracy: 0.9083
# Epoch 163/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1015 - accuracy: 0.9759 - val_loss: 0.3166 - val_accuracy: 0.9083
# Epoch 164/500
# 17/17 [==============================] - 2s 105ms/step - loss: 0.1008 - accuracy: 0.9759 - val_loss: 0.3169 - val_accuracy: 0.9083
# Epoch 165/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.1002 - accuracy: 0.9759 - val_loss: 0.3172 - val_accuracy: 0.9083
# Epoch 166/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0995 - accuracy: 0.9759 - val_loss: 0.3182 - val_accuracy: 0.9083
# Epoch 167/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0992 - accuracy: 0.9759 - val_loss: 0.3172 - val_accuracy: 0.9083
# Epoch 168/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0986 - accuracy: 0.9769 - val_loss: 0.3187 - val_accuracy: 0.9083
# Epoch 169/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0983 - accuracy: 0.9769 - val_loss: 0.3173 - val_accuracy: 0.9083
# Epoch 170/500
# 17/17 [==============================] - 2s 96ms/step - loss: 0.0973 - accuracy: 0.9778 - val_loss: 0.3196 - val_accuracy: 0.9083
# Epoch 171/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0966 - accuracy: 0.9778 - val_loss: 0.3174 - val_accuracy: 0.9083
# Epoch 172/500
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0960 - accuracy: 0.9778 - val_loss: 0.3198 - val_accuracy: 0.9083
# Epoch 173/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0949 - accuracy: 0.9778 - val_loss: 0.3178 - val_accuracy: 0.9083
# Epoch 174/500
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0946 - accuracy: 0.9778 - val_loss: 0.3188 - val_accuracy: 0.9083
# Epoch 175/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0935 - accuracy: 0.9778 - val_loss: 0.3182 - val_accuracy: 0.9083
# Epoch 176/500
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0934 - accuracy: 0.9778 - val_loss: 0.3193 - val_accuracy: 0.9083
# Epoch 177/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0926 - accuracy: 0.9778 - val_loss: 0.3188 - val_accuracy: 0.9083
# Epoch 178/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0920 - accuracy: 0.9778 - val_loss: 0.3195 - val_accuracy: 0.9083
# Epoch 179/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0912 - accuracy: 0.9778 - val_loss: 0.3175 - val_accuracy: 0.9083
# Epoch 180/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0901 - accuracy: 0.9778 - val_loss: 0.3175 - val_accuracy: 0.9083
# Epoch 181/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0893 - accuracy: 0.9787 - val_loss: 0.3174 - val_accuracy: 0.9083
# Epoch 182/500
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0888 - accuracy: 0.9787 - val_loss: 0.3163 - val_accuracy: 0.9083
# Epoch 183/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0882 - accuracy: 0.9787 - val_loss: 0.3176 - val_accuracy: 0.9083
# Epoch 184/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0873 - accuracy: 0.9787 - val_loss: 0.3160 - val_accuracy: 0.9083
# Epoch 185/500
# 17/17 [==============================] - 2s 96ms/step - loss: 0.0866 - accuracy: 0.9787 - val_loss: 0.3171 - val_accuracy: 0.9083
# Epoch 186/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0859 - accuracy: 0.9796 - val_loss: 0.3152 - val_accuracy: 0.9083
# Epoch 187/500
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0856 - accuracy: 0.9796 - val_loss: 0.3165 - val_accuracy: 0.9083
# Epoch 188/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0847 - accuracy: 0.9806 - val_loss: 0.3152 - val_accuracy: 0.9083
# Epoch 189/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0840 - accuracy: 0.9815 - val_loss: 0.3164 - val_accuracy: 0.9083
# Epoch 190/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0835 - accuracy: 0.9815 - val_loss: 0.3145 - val_accuracy: 0.9083
# Epoch 191/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0828 - accuracy: 0.9815 - val_loss: 0.3173 - val_accuracy: 0.9083
# Epoch 192/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0823 - accuracy: 0.9815 - val_loss: 0.3151 - val_accuracy: 0.9083
# Epoch 193/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0819 - accuracy: 0.9815 - val_loss: 0.3157 - val_accuracy: 0.9083
# Epoch 194/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0812 - accuracy: 0.9815 - val_loss: 0.3161 - val_accuracy: 0.9083
# Epoch 195/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0808 - accuracy: 0.9815 - val_loss: 0.3160 - val_accuracy: 0.9000
# Epoch 196/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0801 - accuracy: 0.9815 - val_loss: 0.3163 - val_accuracy: 0.9083
# Epoch 197/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0797 - accuracy: 0.9824 - val_loss: 0.3174 - val_accuracy: 0.9083
# Epoch 198/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0790 - accuracy: 0.9824 - val_loss: 0.3160 - val_accuracy: 0.9083
# Epoch 199/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0787 - accuracy: 0.9833 - val_loss: 0.3175 - val_accuracy: 0.9000
# Epoch 200/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0780 - accuracy: 0.9833 - val_loss: 0.3158 - val_accuracy: 0.9000
# Epoch 201/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0776 - accuracy: 0.9843 - val_loss: 0.3176 - val_accuracy: 0.9000
# Epoch 202/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0769 - accuracy: 0.9833 - val_loss: 0.3161 - val_accuracy: 0.9000
# Epoch 203/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0765 - accuracy: 0.9833 - val_loss: 0.3171 - val_accuracy: 0.9000
# Epoch 204/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0757 - accuracy: 0.9833 - val_loss: 0.3172 - val_accuracy: 0.9000
# Epoch 205/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0753 - accuracy: 0.9833 - val_loss: 0.3172 - val_accuracy: 0.9000
# Epoch 206/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0749 - accuracy: 0.9843 - val_loss: 0.3158 - val_accuracy: 0.9000
# Epoch 207/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0746 - accuracy: 0.9843 - val_loss: 0.3169 - val_accuracy: 0.9000
# Epoch 208/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0737 - accuracy: 0.9843 - val_loss: 0.3161 - val_accuracy: 0.9000
# Epoch 209/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0734 - accuracy: 0.9843 - val_loss: 0.3161 - val_accuracy: 0.9000
# Epoch 210/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0726 - accuracy: 0.9843 - val_loss: 0.3181 - val_accuracy: 0.9000
# Epoch 211/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0723 - accuracy: 0.9852 - val_loss: 0.3160 - val_accuracy: 0.9000
# Epoch 212/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0718 - accuracy: 0.9852 - val_loss: 0.3182 - val_accuracy: 0.9000
# Epoch 213/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0714 - accuracy: 0.9852 - val_loss: 0.3175 - val_accuracy: 0.9083
# Epoch 214/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0710 - accuracy: 0.9852 - val_loss: 0.3188 - val_accuracy: 0.9000
# Epoch 215/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0705 - accuracy: 0.9852 - val_loss: 0.3173 - val_accuracy: 0.8917
# Epoch 216/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0697 - accuracy: 0.9861 - val_loss: 0.3189 - val_accuracy: 0.9083
# Epoch 217/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0695 - accuracy: 0.9852 - val_loss: 0.3173 - val_accuracy: 0.9000
# Epoch 218/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0686 - accuracy: 0.9861 - val_loss: 0.3196 - val_accuracy: 0.9000
# Epoch 219/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0682 - accuracy: 0.9861 - val_loss: 0.3190 - val_accuracy: 0.9000
# Epoch 220/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0679 - accuracy: 0.9861 - val_loss: 0.3197 - val_accuracy: 0.9000
# Epoch 221/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0676 - accuracy: 0.9870 - val_loss: 0.3196 - val_accuracy: 0.8917
# Epoch 222/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0667 - accuracy: 0.9861 - val_loss: 0.3213 - val_accuracy: 0.9000
# Epoch 223/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0666 - accuracy: 0.9870 - val_loss: 0.3193 - val_accuracy: 0.9000
# Epoch 224/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0658 - accuracy: 0.9880 - val_loss: 0.3212 - val_accuracy: 0.9000
# Epoch 225/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0654 - accuracy: 0.9870 - val_loss: 0.3210 - val_accuracy: 0.9000
# Epoch 226/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0651 - accuracy: 0.9880 - val_loss: 0.3200 - val_accuracy: 0.9000
# Epoch 227/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0646 - accuracy: 0.9880 - val_loss: 0.3215 - val_accuracy: 0.9000
# Epoch 228/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0642 - accuracy: 0.9889 - val_loss: 0.3208 - val_accuracy: 0.9000
# Epoch 229/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0638 - accuracy: 0.9880 - val_loss: 0.3222 - val_accuracy: 0.9000
# Epoch 230/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0634 - accuracy: 0.9889 - val_loss: 0.3220 - val_accuracy: 0.9000
# Epoch 231/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0631 - accuracy: 0.9889 - val_loss: 0.3225 - val_accuracy: 0.9000
# Epoch 232/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0624 - accuracy: 0.9907 - val_loss: 0.3228 - val_accuracy: 0.9000
# Epoch 233/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0622 - accuracy: 0.9889 - val_loss: 0.3232 - val_accuracy: 0.9000
# Epoch 234/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0619 - accuracy: 0.9907 - val_loss: 0.3230 - val_accuracy: 0.9000
# Epoch 235/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0612 - accuracy: 0.9907 - val_loss: 0.3230 - val_accuracy: 0.9000
# Epoch 236/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0611 - accuracy: 0.9889 - val_loss: 0.3245 - val_accuracy: 0.9000
# Epoch 237/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0605 - accuracy: 0.9907 - val_loss: 0.3249 - val_accuracy: 0.9000
# Epoch 238/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0602 - accuracy: 0.9917 - val_loss: 0.3248 - val_accuracy: 0.9000
# Epoch 239/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0595 - accuracy: 0.9907 - val_loss: 0.3259 - val_accuracy: 0.9000
# Epoch 240/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0593 - accuracy: 0.9907 - val_loss: 0.3270 - val_accuracy: 0.9000
# Epoch 241/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0586 - accuracy: 0.9917 - val_loss: 0.3271 - val_accuracy: 0.9000
# Epoch 242/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0584 - accuracy: 0.9917 - val_loss: 0.3275 - val_accuracy: 0.9000
# Epoch 243/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0581 - accuracy: 0.9917 - val_loss: 0.3280 - val_accuracy: 0.8917
# Epoch 244/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0573 - accuracy: 0.9917 - val_loss: 0.3273 - val_accuracy: 0.9000
# Epoch 245/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0573 - accuracy: 0.9917 - val_loss: 0.3284 - val_accuracy: 0.8917
# Epoch 246/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0566 - accuracy: 0.9917 - val_loss: 0.3296 - val_accuracy: 0.9000
# Epoch 247/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0560 - accuracy: 0.9917 - val_loss: 0.3284 - val_accuracy: 0.9000
# Epoch 248/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0559 - accuracy: 0.9926 - val_loss: 0.3293 - val_accuracy: 0.9000
# Epoch 249/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0558 - accuracy: 0.9917 - val_loss: 0.3296 - val_accuracy: 0.8917
# Epoch 250/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0548 - accuracy: 0.9926 - val_loss: 0.3294 - val_accuracy: 0.9000
# Epoch 251/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0546 - accuracy: 0.9926 - val_loss: 0.3306 - val_accuracy: 0.9000
# Epoch 252/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0543 - accuracy: 0.9926 - val_loss: 0.3314 - val_accuracy: 0.9000
# Epoch 253/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0538 - accuracy: 0.9926 - val_loss: 0.3309 - val_accuracy: 0.9000
# Epoch 254/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0533 - accuracy: 0.9926 - val_loss: 0.3312 - val_accuracy: 0.8917
# Epoch 255/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0531 - accuracy: 0.9926 - val_loss: 0.3309 - val_accuracy: 0.8917
# Epoch 256/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0524 - accuracy: 0.9926 - val_loss: 0.3336 - val_accuracy: 0.8917
# Epoch 257/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0521 - accuracy: 0.9926 - val_loss: 0.3308 - val_accuracy: 0.8917
# Epoch 258/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0518 - accuracy: 0.9935 - val_loss: 0.3326 - val_accuracy: 0.8917
# Epoch 259/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0513 - accuracy: 0.9935 - val_loss: 0.3315 - val_accuracy: 0.9000
# Epoch 260/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0512 - accuracy: 0.9935 - val_loss: 0.3346 - val_accuracy: 0.8917
# Epoch 261/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0506 - accuracy: 0.9935 - val_loss: 0.3329 - val_accuracy: 0.8917
# Epoch 262/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0503 - accuracy: 0.9935 - val_loss: 0.3360 - val_accuracy: 0.8917
# Epoch 263/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0500 - accuracy: 0.9935 - val_loss: 0.3328 - val_accuracy: 0.8917
# Epoch 264/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0498 - accuracy: 0.9935 - val_loss: 0.3348 - val_accuracy: 0.8917
# Epoch 265/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0491 - accuracy: 0.9944 - val_loss: 0.3367 - val_accuracy: 0.8917
# Epoch 266/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0490 - accuracy: 0.9935 - val_loss: 0.3336 - val_accuracy: 0.9000
# Epoch 267/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0487 - accuracy: 0.9944 - val_loss: 0.3385 - val_accuracy: 0.8917
# Epoch 268/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0482 - accuracy: 0.9944 - val_loss: 0.3353 - val_accuracy: 0.9000
# Epoch 269/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0481 - accuracy: 0.9944 - val_loss: 0.3391 - val_accuracy: 0.8917
# Epoch 270/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0475 - accuracy: 0.9944 - val_loss: 0.3376 - val_accuracy: 0.8917
# Epoch 271/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0473 - accuracy: 0.9944 - val_loss: 0.3380 - val_accuracy: 0.9000
# Epoch 272/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0470 - accuracy: 0.9944 - val_loss: 0.3386 - val_accuracy: 0.9000
# Epoch 273/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0464 - accuracy: 0.9944 - val_loss: 0.3412 - val_accuracy: 0.8917
# Epoch 274/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0462 - accuracy: 0.9944 - val_loss: 0.3385 - val_accuracy: 0.9000
# Epoch 275/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0462 - accuracy: 0.9944 - val_loss: 0.3410 - val_accuracy: 0.9000
# Epoch 276/500
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0456 - accuracy: 0.9954 - val_loss: 0.3424 - val_accuracy: 0.8917
# Epoch 277/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0453 - accuracy: 0.9954 - val_loss: 0.3406 - val_accuracy: 0.9000
# Epoch 278/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0452 - accuracy: 0.9954 - val_loss: 0.3435 - val_accuracy: 0.9000
# Epoch 279/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0446 - accuracy: 0.9954 - val_loss: 0.3431 - val_accuracy: 0.8917
# Epoch 280/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0443 - accuracy: 0.9954 - val_loss: 0.3424 - val_accuracy: 0.9000
# Epoch 281/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0441 - accuracy: 0.9954 - val_loss: 0.3448 - val_accuracy: 0.9000
# Epoch 282/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0438 - accuracy: 0.9954 - val_loss: 0.3429 - val_accuracy: 0.9000
# Epoch 283/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0437 - accuracy: 0.9954 - val_loss: 0.3466 - val_accuracy: 0.9000
# Epoch 284/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0431 - accuracy: 0.9954 - val_loss: 0.3470 - val_accuracy: 0.9000
# Epoch 285/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0428 - accuracy: 0.9954 - val_loss: 0.3475 - val_accuracy: 0.9000
# Epoch 286/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0429 - accuracy: 0.9954 - val_loss: 0.3488 - val_accuracy: 0.8917
# Epoch 287/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0422 - accuracy: 0.9954 - val_loss: 0.3488 - val_accuracy: 0.9000
# Epoch 288/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0420 - accuracy: 0.9954 - val_loss: 0.3508 - val_accuracy: 0.8917
# Epoch 289/500
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0417 - accuracy: 0.9954 - val_loss: 0.3490 - val_accuracy: 0.8917
# Epoch 290/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0414 - accuracy: 0.9954 - val_loss: 0.3519 - val_accuracy: 0.8917
# Epoch 291/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0411 - accuracy: 0.9954 - val_loss: 0.3510 - val_accuracy: 0.8917
# Epoch 292/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0408 - accuracy: 0.9954 - val_loss: 0.3526 - val_accuracy: 0.8917
# Epoch 293/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0403 - accuracy: 0.9954 - val_loss: 0.3512 - val_accuracy: 0.8917
# Epoch 294/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0402 - accuracy: 0.9954 - val_loss: 0.3570 - val_accuracy: 0.8917
# Epoch 295/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0400 - accuracy: 0.9954 - val_loss: 0.3519 - val_accuracy: 0.8833
# Epoch 296/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0399 - accuracy: 0.9954 - val_loss: 0.3575 - val_accuracy: 0.8833
# Epoch 297/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0393 - accuracy: 0.9954 - val_loss: 0.3558 - val_accuracy: 0.8917
# Epoch 298/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0391 - accuracy: 0.9963 - val_loss: 0.3542 - val_accuracy: 0.8917
# Epoch 299/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0388 - accuracy: 0.9963 - val_loss: 0.3589 - val_accuracy: 0.8917
# Epoch 300/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0384 - accuracy: 0.9963 - val_loss: 0.3576 - val_accuracy: 0.8833
# Epoch 301/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0379 - accuracy: 0.9963 - val_loss: 0.3590 - val_accuracy: 0.8917
# Epoch 302/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0378 - accuracy: 0.9963 - val_loss: 0.3602 - val_accuracy: 0.8917
# Epoch 303/500
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0375 - accuracy: 0.9963 - val_loss: 0.3600 - val_accuracy: 0.8833
# Epoch 304/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0370 - accuracy: 0.9963 - val_loss: 0.3605 - val_accuracy: 0.8833
# Epoch 305/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0367 - accuracy: 0.9963 - val_loss: 0.3596 - val_accuracy: 0.8833
# Epoch 306/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0366 - accuracy: 0.9963 - val_loss: 0.3643 - val_accuracy: 0.8833
# Epoch 307/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0361 - accuracy: 0.9963 - val_loss: 0.3600 - val_accuracy: 0.8833
# Epoch 308/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0359 - accuracy: 0.9963 - val_loss: 0.3651 - val_accuracy: 0.8833
# Epoch 309/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0355 - accuracy: 0.9963 - val_loss: 0.3633 - val_accuracy: 0.8833
# Epoch 310/500
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0353 - accuracy: 0.9963 - val_loss: 0.3655 - val_accuracy: 0.8833
# Epoch 311/500
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0348 - accuracy: 0.9963 - val_loss: 0.3645 - val_accuracy: 0.8833
# Epoch 312/500
# 13/17 [=====================>........] - ETA: 0s - loss: 0.0348 - accuracy: 0.9964

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history3.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')

# %% [markdown]
# **Congratulations**! You've finished the assignment and built two models: One that recognizes  smiles, and another that recognizes SIGN language with almost 80% accuracy on the test set. In addition to that, you now also understand the applications of two Keras APIs: Sequential and Functional. Nicely done!
#
# By now, you know a bit about how the Functional API works and may have glimpsed the possibilities. In your next assignment, you'll really get a feel for its power when you get the opportunity to build a very deep ConvNet, using ResNets!

# %% [markdown]
# <a name='6'></a>
# ## 6 - Bibliography
#
# You're always encouraged to read the official documentation. To that end, you can find the docs for the Sequential and Functional APIs here:
#
# https://www.tensorflow.org/guide/keras/sequential_model
#
# https://www.tensorflow.org/guide/keras/functional
